# %%
import xarray as xr

# %%
file_old = r'/scratch/project_2000908/nousu/SpaFHy_RESULTS/FIRE_5_24/firespread_gis_32m_current_5_24.nc'
file_new = r'/scratch/project_2000908/nousu/SpaFHy_RESULTS/FIRE_1_25/firespread_gis_32m_noroads_1_2025.nc'

# %%
old = xr.open_dataset(file_old)
new = xr.open_dataset(file_new)

# %%
new
# Out:
# <xarray.Dataset>
# Dimensions:          (lat: 250, lon: 375)
# Coordinates:
#   * lat              (lat) float64 6.865e+06 6.865e+06 ... 6.857e+06 6.857e+06
#   * lon              (lon) float64 3.48e+05 3.48e+05 ... 3.599e+05 3.6e+05
# Data variables:
#     catchment_mask   (lat, lon) float32 ...
#     stand_density    (lat, lon) float32 ...
#     stand_age        (lat, lon) float32 ...
#     canopy_height    (lat, lon) float32 ...
#     canopy_diameter  (lat, lon) float32 ...
#     basal_area       (lat, lon) float32 ...
#     LAI_conif        (lat, lon) float32 ...
#     LAI_decid        (lat, lon) float32 ...
#     dem              (lat, lon) float32 ...
#     lake_mask        (lat, lon) float32 ...
#     road_mask        (lat, lon) float32 ...
# Attributes:
#     description:  GIS dataset
#     history:      created 2025-01-27 14:28:34
#     source:       MML, GTK, LUKE

# %%
new['LAI_conif'].plot()

# %%
old['nonland_mask'].plot()

# %%
old['road_mask'].plot()
